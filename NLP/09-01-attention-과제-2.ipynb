# %% [markdown]
# # Install

# %%
# !pip install sentencepiece
# Out:
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/14/67/e42bd1181472c95c8cda79305df848264f2a7f62740995a46945d9797b67/sentencepiece-0.1.95-cp36-cp36m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 8.6MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.95

# %% [markdown]
# # Evn

# %%
import os
import random
import shutil
import json
import zipfile
import math
import copy
import collections
import re

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sentencepiece as spm
import tensorflow as tf
import tensorflow.keras.backend as KK

from tqdm.notebook import tqdm

# %%
# random seed initialize
random_seed = 1234
random.seed(random_seed)
np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# %%
# !nvidia-smi
# Out:
# Mon Feb  8 09:07:53 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8    10W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# google drive mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# data dir
data_dir = '/content/drive/MyDrive/data/data'
os.listdir(data_dir)
# Out:
# ['ko_32000.model',
#  'ko_32000.vocab',
#  'kowiki',
#  'mycorpus',
#  '.ipynb_checkpoints',
#  'my_vocab.model',
#  'nsmc',
#  'quora',
#  'songys']

# %%
# songys chatbot dir
songys_dir = os.path.join(data_dir, 'songys')
if not os.path.exists(songys_dir):
    os.makedirs(songys_dir)
os.listdir(songys_dir)
# Out:
# ['ChatbotData.csv', 'lstm.csv', 'lstm.hdf5', 'lstm_dot.csv', 'lstm_dot.hdf5']

# %% [markdown]
# # Attention

# %%
def get_pad_mask(tokens, i_pad=0):
    """
    pad mask 계산하는 함수
    :param tokens: tokens (bs, n_seq)
    :param i_pad: id of pad
    :return mask: pad mask (pad: 1, other: 0)
    """
    # 0인 부분 확인
    mask = tf.math.equal(tokens, i_pad)
    # boolean -> float 32
    mask = tf.cast(mask, tf.float32)
    # expand dimension for n_seq
    mask = tf.expand_dims(mask, axis=1)
    return mask

# %%
class ScaleDotProductAttention(tf.keras.layers.Layer):
    """
    Scale Dot Product Attention Class
    """
    def __init__(self, name="scale_dot_product_attention"):
        """
        생성자
        :param name: layer name
        """
        super().__init__(name=name)

    def call(self, inputs):
        """
        layer 실행
        :param inputs: Q, K, V, attn_mask tuple
        :return attn_out: attention 실행 결과
        """
        Q, K, V, attn_mask = inputs
        # matmul Q, K (transpose_b=True)
        attn_score = tf.matmul(Q, K, transpose_b=True)
        # get scale = d_model ** 0.5
        scale = tf.math.sqrt(tf.cast(tf.shape(K)[-1], tf.float32))
        # divide by scale
        attn_scale = tf.math.divide(attn_score, scale)
        # do mask (subtract 1e-9 for masked value)
        attn_scale -= 1.e9 * attn_mask
        # calculate attention prob
        attn_prob = tf.nn.softmax(attn_scale, axis=-1)
        # weighted sum of V
        attn_out = tf.matmul(attn_prob, V)
        return attn_out

# %% [markdown]
# # Vocabulary & config

# %%
# vocab loading
vocab = spm.SentencePieceProcessor()
vocab.load(os.path.join(data_dir, 'ko_32000.model'))
# Out:
# True

# %%
n_vocab = len(vocab)  # number of vocabulary
n_enc_seq = 32  # number of sequence 1
n_dec_seq = 40  # number of sequence 2
d_model = 256  # dimension of model

# %% [markdown]
# # 모델링

# %%
def build_model(n_vocab, d_model, n_enc_seq, n_dec_seq):
    """
    문장 유사도 비교 모델
    :param n_vocab: vocabulary 단어 수
    :param d_model: 단어를 의미하는 벡터의 차원 수
    :param n_enc_seq: encoder 문장 길이 (단어 수)
    :param n_dec_seq: decoder 문장 길이 (단어 수)
    """
    inputs_enc = tf.keras.layers.Input((n_enc_seq,))  # (bs, n_enc_seq)
    inputs_dec = tf.keras.layers.Input((n_dec_seq,))  # (bs, n_dec_seq)
    # pad mask 생성
    ###############################################
    inputs_enc_mask = get_pad_mask(inputs_enc)
    inputs_dec_mask = get_pad_mask(inputs_dec)

    print(inputs_enc_mask)
    
    ###############################################
    # 입력 단어를 vector로 변환
    embedding = tf.keras.layers.Embedding(n_vocab, d_model)
    hidden_enc = embedding(inputs_enc)  # (bs, n_enc_seq, d_model)
    hidden_dec = embedding(inputs_dec)  # (bs, n_dec_seq, d_model)
    # encoder LSTM
    fw_cell = tf.keras.layers.LSTM(units=d_model, return_sequences=True, return_state=True)
    bw_cell = tf.keras.layers.LSTM(units=d_model, go_backwards=True, return_sequences=True, return_state=True)
    lstm_enc = tf.keras.layers.Bidirectional(fw_cell, backward_layer=bw_cell)
    hidden_enc, fw_h, fw_c, bw_h, bw_c = lstm_enc(hidden_enc)  # (bs, n_enc_seq, d_model * 2), (bs, d_model), (bs, d_model), (bs, d_model), (bs, d_model)
    # concat hidden & cell
    s_h = tf.concat([fw_h, bw_h], axis=-1)  # (bs, d_model * 2)
    s_c = tf.concat([fw_c, bw_c], axis=-1)  # (bs, d_model * 2)
    # decoder LSTM
    lstm_dec = tf.keras.layers.LSTM(units=d_model * 2, return_sequences=True)
    hidden_dec = lstm_dec(hidden_dec, initial_state=[s_h, s_c])  # (bs, n_dec_seq, d_model)
    # ScaleDotProductAttention 실행
    ##############################################
    Q = hidden_enc
    K = hidden_enc
    V = hidden_enc
    attention = ScaleDotProductAttention()
    attn_out = attention((Q, K, V, inputs_enc_mask))

    Q = hidden_dec
    K = hidden_dec
    V = hidden_dec

    attn_out = attention((Q, K, V, inputs_dec_mask))
    attn_out

    ##############################################
    # concat output
    dec_out = tf.concat([attn_out, hidden_dec], axis=-1)
    # 다음단어 예측
    dense_out = tf.keras.layers.Dense(units=n_vocab, activation=tf.nn.softmax)
    outputs = dense_out(dec_out)  # (bs, n_dec_seq, n_vocab)
    # 학습할 모델 선언
    model = tf.keras.Model(inputs=(inputs_enc, inputs_dec), outputs=outputs)
    return model

# %%
# 모델 생성
model = build_model(len(vocab), d_model, n_enc_seq, n_dec_seq)
# 모델 내용 그래프 출력
tf.keras.utils.plot_model(model, 'model.png', show_shapes=True)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 1, 32), dtype=tf.float32, name=None), name='tf.expand_dims_28/ExpandDims:0', description="created by layer 'tf.expand_dims_28'")

# %% [markdown]
# # Loss & Acc

# %%
def lm_loss(y_true, y_pred):
    """
    pad 부분을 제외하고 loss를 계산하는 함수
    :param y_true: 정답
    :param y_pred: 예측 값
    :retrun loss: pad 부분이 제외된 loss 값
    """
    # loss = sparse_entropy = tf.keras.losses.SparseCategoricalCrossentropy()(y_true, y_pred)
    loss = tf.keras.losses.SparseCategoricalCrossentropy(reduction=tf.keras.losses.Reduction.NONE)(y_true, y_pred)
    mask = tf.not_equal(y_true, 0)
    mask = tf.cast(mask, tf.float32)
    # print(mask)
    loss *= mask
    return loss

# %%
def lm_acc(y_true, y_pred):
    """
    pad 부분을 제외하고 accuracy를 계산하는 함수
    :param y_true: 정답
    :param y_pred: 예측 값
    :retrun loss: pad 부분이 제외된 accuracy 값
    """
    y_true = tf.cast(y_true, tf.float32)
    # print(y_true)
    y_pred_class = tf.cast(tf.argmax(y_pred, axis=-1), tf.float32)
    # print(y_pred_class)
    matches = tf.cast(tf.equal(y_true, y_pred_class), tf.float32)
    # print(matches)
    mask = tf.not_equal(y_true, 0)
    mask = tf.cast(mask, tf.float32)
    # print(mask)
    matches *= mask
    # print(matches)
    # accuracy = tf.reduce_sum(matches) / tf.maximum(tf.reduce_sum(tf.ones_like(matches)), 1)
    accuracy = tf.reduce_sum(matches) / tf.maximum(tf.reduce_sum(mask), 1)
    return accuracy

# %% [markdown]
# # All Data Project

# %% [markdown]
# ## Data

# %%
df_train = pd.read_csv(os.path.join(songys_dir, 'ChatbotData.csv'))
print(len(df_train))
df_train = df_train.dropna()
print(len(df_train))
df_train
# Out:
# 11823
# 11823
#                              Q                         A  label
# 0                       12시 땡!                하루가 또 가네요.      0
# 1                  1지망 학교 떨어졌어                 위로해 드립니다.      0
# 2                 3박4일 놀러가고 싶다               여행은 언제나 좋죠.      0
# 3              3박4일 정도 놀러가고 싶다               여행은 언제나 좋죠.      0
# 4                      PPL 심하네                눈살이 찌푸려지죠.      0
# ...                        ...                       ...    ...
# 11818           훔쳐보는 것도 눈치 보임.        티가 나니까 눈치가 보이는 거죠!      2
# 11819           훔쳐보는 것도 눈치 보임.             훔쳐보는 거 티나나봐요.      2
# 11820              흑기사 해주는 짝남.                    설렜겠어요.      2
# 11821  힘든 연애 좋은 연애라는게 무슨 차이일까?  잘 헤어질 수 있는 사이 여부인 거 같아요.      2
# 11822               힘들어서 결혼할까봐        도피성 결혼은 하지 않길 바라요.      2
#
# [11823 rows x 3 columns]

# %%
def load_data(df, n_enc_seq, n_dec_seq):
    """
    Quora 학습 데이터 생성
    :param df: data frame
    :param n_enc_seq: number of encoder sequence
    :param n_dec_seq: number of decoder sequence
    :return enc_inputs: encoder input data
    :return dec_inputs: decoder input data
    :return labels: label data
    """
    n_enc_max = n_enc_seq
    n_dec_max = n_dec_seq - 1
    enc_inputs = np.zeros((len(df), n_enc_seq)).astype(np.int32)
    dec_inputs = np.zeros((len(df), n_dec_seq)).astype(np.int32)
    labels = np.zeros((len(df), n_dec_seq)).astype(np.int32)
    index = 0
    for i, row in tqdm(df.iterrows(), total=len(df)):
        # tokens 저장
        Q = row['Q']
        A = row['A']

        tokens_q = vocab.encode_as_pieces(Q)
        tokens_a = vocab.encode_as_pieces(A)

        tokens_ids_q = vocab.encode_as_ids(Q)[:n_enc_max]
        tokens_ids_a = vocab.encode_as_ids(A)[:n_dec_max]

        tokens_dec_in = [vocab.bos_id()] + tokens_ids_a
        tokens_dec_out = tokens_ids_a + [vocab.eos_id()]

        tokens_ids_q += [0] * (n_enc_seq - len(tokens_ids_q))
        tokens_dec_in += [0] * (n_dec_seq - len(tokens_dec_in))
        tokens_dec_out += [0] * (n_dec_seq - len(tokens_dec_out))

        enc_inputs[index] = tokens_ids_q
        dec_inputs[index] = tokens_dec_in
        labels[index] = tokens_dec_out
        index += 1
    return enc_inputs, dec_inputs, labels

# %%
# train data 생성
train_enc_inputs, train_dec_inputs, train_labels = load_data(df_train, n_enc_seq, n_dec_seq)
train_enc_inputs, train_dec_inputs, train_labels
# Out:
# HBox(children=(FloatProgress(value=0.0, max=11823.0), HTML(value='')))
# (array([[   89,    56,    10, ...,     0,     0,     0],
#         [   35,    47,  1004, ...,     0,     0,     0],
#         [   38,   819,   362, ...,     0,     0,     0],
#         ...,
#         [ 2886,  9525, 21930, ...,     0,     0,     0],
#         [10736,  8256,  1172, ...,     0,     0,     0],
#         [26128,    70,  1381, ...,     0,     0,     0]], dtype=int32),
#  array([[    2,  2261,    19, ...,     0,     0,     0],
#         [    2,  4594,    61, ...,     0,     0,     0],
#         [    2,  2350,    18, ...,     0,     0,     0],
#         ...,
#         [    2,  1522,     1, ...,     0,     0,     0],
#         [    2,   441, 10316, ...,     0,     0,     0],
#         [    2, 16665,    90, ...,     0,     0,     0]], dtype=int32),
#  array([[ 2261,    19,   375, ...,     0,     0,     0],
#         [ 4594,    61,   929, ...,     0,     0,     0],
#         [ 2350,    18,  9001, ...,     0,     0,     0],
#         ...,
#         [ 1522,     1, 12273, ...,     0,     0,     0],
#         [  441, 10316,   515, ...,     0,     0,     0],
#         [16665,    90,  1381, ...,     0,     0,     0]], dtype=int32))

# %% [markdown]
# ## 학습

# %%
# 모델 생성
model = build_model(len(vocab), d_model, n_enc_seq, n_dec_seq)
# 모델 내용 그래프 출력
tf.keras.utils.plot_model(model, 'model.png', show_shapes=True)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 1, 32), dtype=tf.float32, name=None), name='tf.expand_dims_30/ExpandDims:0', description="created by layer 'tf.expand_dims_30'")

# %%
# 모델 loss, optimizer, metric 정의
model.compile(loss=lm_loss, optimizer='adam', metrics=[lm_acc])

# %%
# early stopping
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='lm_acc', patience=5)
# save weights callback
save_weights = tf.keras.callbacks.ModelCheckpoint(os.path.join(songys_dir, 'lstm_scale_dot.hdf5'),
                                                  monitor='lm_acc',
                                                  verbose=1,
                                                  save_best_only=True,
                                                  mode="max",
                                                  save_freq="epoch",
                                                  save_weights_only=True)
# csv logger
csv_logger = tf.keras.callbacks.CSVLogger(os.path.join(songys_dir, 'lstm_scale_dot.csv'))

# %%
# 모델 학습
history = model.fit((train_enc_inputs, train_dec_inputs),
                    train_labels,
                    epochs=100,
                    batch_size=256,
                    callbacks=[early_stopping, save_weights, csv_logger])
# Out:
# Epoch 1/100
# 47/47 [==============================] - 45s 740ms/step - loss: 1.8546 - lm_acc: 0.1020
#
# Epoch 00001: lm_acc improved from -inf to 0.11077, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 2/100
# 47/47 [==============================] - 36s 760ms/step - loss: 1.2937 - lm_acc: 0.1550
#
# Epoch 00002: lm_acc improved from 0.11077 to 0.17715, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 3/100
# 47/47 [==============================] - 37s 778ms/step - loss: 1.1601 - lm_acc: 0.2521
#
# Epoch 00003: lm_acc improved from 0.17715 to 0.27211, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 4/100
# 47/47 [==============================] - 37s 788ms/step - loss: 1.0597 - lm_acc: 0.3092
#
# Epoch 00004: lm_acc improved from 0.27211 to 0.32428, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 5/100
# 47/47 [==============================] - 37s 791ms/step - loss: 0.9841 - lm_acc: 0.3676
#
# Epoch 00005: lm_acc improved from 0.32428 to 0.37722, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 6/100
# 47/47 [==============================] - 38s 803ms/step - loss: 0.9134 - lm_acc: 0.4030
#
# Epoch 00006: lm_acc improved from 0.37722 to 0.40636, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 7/100
# 47/47 [==============================] - 38s 807ms/step - loss: 0.8668 - lm_acc: 0.4259
#
# Epoch 00007: lm_acc improved from 0.40636 to 0.43271, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 8/100
# 47/47 [==============================] - 38s 809ms/step - loss: 0.8178 - lm_acc: 0.4496
#
# Epoch 00008: lm_acc improved from 0.43271 to 0.45399, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 9/100
# 47/47 [==============================] - 38s 805ms/step - loss: 0.7740 - lm_acc: 0.4694
#
# Epoch 00009: lm_acc improved from 0.45399 to 0.47419, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 10/100
# 47/47 [==============================] - 38s 808ms/step - loss: 0.7358 - lm_acc: 0.4905
#
# Epoch 00010: lm_acc improved from 0.47419 to 0.49278, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 11/100
# 47/47 [==============================] - 38s 811ms/step - loss: 0.6960 - lm_acc: 0.5121
#
# Epoch 00011: lm_acc improved from 0.49278 to 0.51370, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 12/100
# 47/47 [==============================] - 38s 810ms/step - loss: 0.6563 - lm_acc: 0.5288
#
# Epoch 00012: lm_acc improved from 0.51370 to 0.53193, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 13/100
# 47/47 [==============================] - 38s 815ms/step - loss: 0.6204 - lm_acc: 0.5507
#
# Epoch 00013: lm_acc improved from 0.53193 to 0.55236, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 14/100
# 47/47 [==============================] - 38s 812ms/step - loss: 0.5898 - lm_acc: 0.5674
#
# Epoch 00014: lm_acc improved from 0.55236 to 0.57301, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 15/100
# 47/47 [==============================] - 38s 811ms/step - loss: 0.5493 - lm_acc: 0.5930
#
# Epoch 00015: lm_acc improved from 0.57301 to 0.59594, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 16/100
# 47/47 [==============================] - 38s 809ms/step - loss: 0.5091 - lm_acc: 0.6163
#
# Epoch 00016: lm_acc improved from 0.59594 to 0.61818, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 17/100
# 47/47 [==============================] - 38s 810ms/step - loss: 0.4808 - lm_acc: 0.6359
#
# Epoch 00017: lm_acc improved from 0.61818 to 0.63943, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 18/100
# 47/47 [==============================] - 38s 811ms/step - loss: 0.4476 - lm_acc: 0.6593
#
# Epoch 00018: lm_acc improved from 0.63943 to 0.66173, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 19/100
# 47/47 [==============================] - 38s 813ms/step - loss: 0.4160 - lm_acc: 0.6846
#
# Epoch 00019: lm_acc improved from 0.66173 to 0.68416, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 20/100
# 47/47 [==============================] - 38s 811ms/step - loss: 0.3830 - lm_acc: 0.7072
#
# Epoch 00020: lm_acc improved from 0.68416 to 0.70754, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 21/100
# 47/47 [==============================] - 38s 811ms/step - loss: 0.3556 - lm_acc: 0.7289
#
# Epoch 00021: lm_acc improved from 0.70754 to 0.72700, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 22/100
# 47/47 [==============================] - 38s 810ms/step - loss: 0.3309 - lm_acc: 0.7492
#
# Epoch 00022: lm_acc improved from 0.72700 to 0.74800, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 23/100
# 47/47 [==============================] - 38s 811ms/step - loss: 0.3072 - lm_acc: 0.7678
#
# Epoch 00023: lm_acc improved from 0.74800 to 0.76846, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 24/100
# 47/47 [==============================] - 38s 814ms/step - loss: 0.2820 - lm_acc: 0.7863
#
# Epoch 00024: lm_acc improved from 0.76846 to 0.78617, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 25/100
# 47/47 [==============================] - 38s 811ms/step - loss: 0.2620 - lm_acc: 0.8013
#
# Epoch 00025: lm_acc improved from 0.78617 to 0.80273, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 26/100
# 47/47 [==============================] - 38s 810ms/step - loss: 0.2401 - lm_acc: 0.8192
#
# Epoch 00026: lm_acc improved from 0.80273 to 0.81881, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 27/100
# 47/47 [==============================] - 38s 807ms/step - loss: 0.2203 - lm_acc: 0.8375
#
# Epoch 00027: lm_acc improved from 0.81881 to 0.83445, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 28/100
# 47/47 [==============================] - 38s 812ms/step - loss: 0.2033 - lm_acc: 0.8489
#
# Epoch 00028: lm_acc improved from 0.83445 to 0.84859, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 29/100
# 47/47 [==============================] - 38s 811ms/step - loss: 0.1893 - lm_acc: 0.8624
#
# Epoch 00029: lm_acc improved from 0.84859 to 0.86398, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 30/100
# 47/47 [==============================] - 38s 808ms/step - loss: 0.1720 - lm_acc: 0.8762
#
# Epoch 00030: lm_acc improved from 0.86398 to 0.87594, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 31/100
# 47/47 [==============================] - 38s 812ms/step - loss: 0.1607 - lm_acc: 0.8873
#
# Epoch 00031: lm_acc improved from 0.87594 to 0.88727, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 32/100
# 47/47 [==============================] - 38s 813ms/step - loss: 0.1460 - lm_acc: 0.8992
#
# Epoch 00032: lm_acc improved from 0.88727 to 0.89793, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 33/100
# 47/47 [==============================] - 38s 810ms/step - loss: 0.1345 - lm_acc: 0.9081
#
# Epoch 00033: lm_acc improved from 0.89793 to 0.90756, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 34/100
# 47/47 [==============================] - 38s 811ms/step - loss: 0.1222 - lm_acc: 0.9189
#
# Epoch 00034: lm_acc improved from 0.90756 to 0.91818, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 35/100
# 47/47 [==============================] - 38s 812ms/step - loss: 0.1114 - lm_acc: 0.9288
#
# Epoch 00035: lm_acc improved from 0.91818 to 0.92703, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 36/100
# 47/47 [==============================] - 38s 809ms/step - loss: 0.1032 - lm_acc: 0.9356
#
# Epoch 00036: lm_acc improved from 0.92703 to 0.93592, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 37/100
# 47/47 [==============================] - 38s 811ms/step - loss: 0.0925 - lm_acc: 0.9425
#
# Epoch 00037: lm_acc improved from 0.93592 to 0.94198, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 38/100
# 47/47 [==============================] - 38s 808ms/step - loss: 0.0864 - lm_acc: 0.9498
#
# Epoch 00038: lm_acc improved from 0.94198 to 0.94906, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 39/100
# 47/47 [==============================] - 38s 810ms/step - loss: 0.0769 - lm_acc: 0.9566
#
# Epoch 00039: lm_acc improved from 0.94906 to 0.95494, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 40/100
# 47/47 [==============================] - 38s 808ms/step - loss: 0.0702 - lm_acc: 0.9624
#
# Epoch 00040: lm_acc improved from 0.95494 to 0.96036, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 41/100
# 47/47 [==============================] - 38s 813ms/step - loss: 0.0652 - lm_acc: 0.9665
#
# Epoch 00041: lm_acc improved from 0.96036 to 0.96543, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 42/100
# 47/47 [==============================] - 38s 807ms/step - loss: 0.0592 - lm_acc: 0.9699
#
# Epoch 00042: lm_acc improved from 0.96543 to 0.96965, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 43/100
# 47/47 [==============================] - 38s 811ms/step - loss: 0.0539 - lm_acc: 0.9743
#
# Epoch 00043: lm_acc improved from 0.96965 to 0.97308, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 44/100
# 47/47 [==============================] - 38s 810ms/step - loss: 0.0497 - lm_acc: 0.9772
#
# Epoch 00044: lm_acc improved from 0.97308 to 0.97604, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 45/100
# 47/47 [==============================] - 38s 812ms/step - loss: 0.0457 - lm_acc: 0.9805
#
# Epoch 00045: lm_acc improved from 0.97604 to 0.97902, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 46/100
# 47/47 [==============================] - 38s 812ms/step - loss: 0.0421 - lm_acc: 0.9823
#
# Epoch 00046: lm_acc improved from 0.97902 to 0.98089, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 47/100
# 47/47 [==============================] - 38s 812ms/step - loss: 0.0397 - lm_acc: 0.9847
#
# Epoch 00047: lm_acc improved from 0.98089 to 0.98313, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 48/100
# 47/47 [==============================] - 38s 808ms/step - loss: 0.0365 - lm_acc: 0.9860
#
# Epoch 00048: lm_acc improved from 0.98313 to 0.98466, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 49/100
# 47/47 [==============================] - 38s 811ms/step - loss: 0.0332 - lm_acc: 0.9885
#
# Epoch 00049: lm_acc improved from 0.98466 to 0.98755, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 50/100
# 47/47 [==============================] - 38s 809ms/step - loss: 0.0304 - lm_acc: 0.9899
#
# Epoch 00050: lm_acc improved from 0.98755 to 0.98899, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 51/100
# 47/47 [==============================] - 38s 808ms/step - loss: 0.0284 - lm_acc: 0.9910
#
# Epoch 00051: lm_acc improved from 0.98899 to 0.99083, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 52/100
# 47/47 [==============================] - 38s 810ms/step - loss: 0.0267 - lm_acc: 0.9920
#
# Epoch 00052: lm_acc improved from 0.99083 to 0.99124, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 53/100
# 47/47 [==============================] - 38s 810ms/step - loss: 0.0250 - lm_acc: 0.9926
#
# Epoch 00053: lm_acc improved from 0.99124 to 0.99245, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 54/100
# 47/47 [==============================] - 38s 812ms/step - loss: 0.0227 - lm_acc: 0.9939
#
# Epoch 00054: lm_acc improved from 0.99245 to 0.99355, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 55/100
# 47/47 [==============================] - 38s 810ms/step - loss: 0.0212 - lm_acc: 0.9942
#
# Epoch 00055: lm_acc improved from 0.99355 to 0.99389, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 56/100
# 47/47 [==============================] - 38s 813ms/step - loss: 0.0192 - lm_acc: 0.9957
#
# Epoch 00056: lm_acc improved from 0.99389 to 0.99529, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 57/100
# 47/47 [==============================] - 38s 809ms/step - loss: 0.0174 - lm_acc: 0.9963
#
# Epoch 00057: lm_acc improved from 0.99529 to 0.99588, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 58/100
# 47/47 [==============================] - 38s 808ms/step - loss: 0.0167 - lm_acc: 0.9967
#
# Epoch 00058: lm_acc improved from 0.99588 to 0.99663, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 59/100
# 47/47 [==============================] - 38s 809ms/step - loss: 0.0154 - lm_acc: 0.9971
#
# Epoch 00059: lm_acc improved from 0.99663 to 0.99712, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 60/100
# 47/47 [==============================] - 38s 810ms/step - loss: 0.0143 - lm_acc: 0.9977
#
# Epoch 00060: lm_acc improved from 0.99712 to 0.99757, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 61/100
# 47/47 [==============================] - 38s 809ms/step - loss: 0.0134 - lm_acc: 0.9981
#
# Epoch 00061: lm_acc improved from 0.99757 to 0.99786, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 62/100
# 47/47 [==============================] - 38s 807ms/step - loss: 0.0127 - lm_acc: 0.9981
#
# Epoch 00062: lm_acc improved from 0.99786 to 0.99818, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 63/100
# 47/47 [==============================] - 38s 807ms/step - loss: 0.0116 - lm_acc: 0.9988
#
# Epoch 00063: lm_acc improved from 0.99818 to 0.99846, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 64/100
# 47/47 [==============================] - 38s 808ms/step - loss: 0.0112 - lm_acc: 0.9986
#
# Epoch 00064: lm_acc improved from 0.99846 to 0.99870, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 65/100
# 47/47 [==============================] - 38s 808ms/step - loss: 0.0103 - lm_acc: 0.9991
#
# Epoch 00065: lm_acc improved from 0.99870 to 0.99893, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 66/100
# 47/47 [==============================] - 38s 809ms/step - loss: 0.0097 - lm_acc: 0.9992
#
# Epoch 00066: lm_acc improved from 0.99893 to 0.99912, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 67/100
# 47/47 [==============================] - 38s 811ms/step - loss: 0.0090 - lm_acc: 0.9993
#
# Epoch 00067: lm_acc improved from 0.99912 to 0.99919, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 68/100
# 47/47 [==============================] - 38s 809ms/step - loss: 0.0086 - lm_acc: 0.9993
#
# Epoch 00068: lm_acc improved from 0.99919 to 0.99922, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 69/100
# 47/47 [==============================] - 38s 810ms/step - loss: 0.0080 - lm_acc: 0.9994
#
# Epoch 00069: lm_acc improved from 0.99922 to 0.99930, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 70/100
# 47/47 [==============================] - 38s 810ms/step - loss: 0.0078 - lm_acc: 0.9995
#
# Epoch 00070: lm_acc improved from 0.99930 to 0.99938, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 71/100
# 47/47 [==============================] - 38s 812ms/step - loss: 0.0072 - lm_acc: 0.9995
#
# Epoch 00071: lm_acc improved from 0.99938 to 0.99950, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 72/100
# 47/47 [==============================] - 38s 812ms/step - loss: 0.0068 - lm_acc: 0.9996
#
# Epoch 00072: lm_acc improved from 0.99950 to 0.99961, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 73/100
# 47/47 [==============================] - 38s 809ms/step - loss: 0.0065 - lm_acc: 0.9996
#
# Epoch 00073: lm_acc improved from 0.99961 to 0.99969, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 74/100
# 47/47 [==============================] - 38s 809ms/step - loss: 0.0060 - lm_acc: 0.9998
#
# Epoch 00074: lm_acc improved from 0.99969 to 0.99971, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 75/100
# 47/47 [==============================] - 38s 807ms/step - loss: 0.0058 - lm_acc: 0.9999
#
# Epoch 00075: lm_acc improved from 0.99971 to 0.99981, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 76/100
# 47/47 [==============================] - 38s 811ms/step - loss: 0.0055 - lm_acc: 0.9999
#
# Epoch 00076: lm_acc improved from 0.99981 to 0.99982, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 77/100
# 47/47 [==============================] - 38s 812ms/step - loss: 0.0052 - lm_acc: 0.9999
#
# Epoch 00077: lm_acc improved from 0.99982 to 0.99985, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 78/100
# 47/47 [==============================] - 38s 807ms/step - loss: 0.0051 - lm_acc: 0.9999
#
# Epoch 00078: lm_acc improved from 0.99985 to 0.99989, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 79/100
# 47/47 [==============================] - 38s 804ms/step - loss: 0.0048 - lm_acc: 0.9999
#
# Epoch 00079: lm_acc improved from 0.99989 to 0.99990, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 80/100
# 47/47 [==============================] - 38s 806ms/step - loss: 0.0046 - lm_acc: 0.9999
#
# Epoch 00080: lm_acc did not improve from 0.99990
# Epoch 81/100
# 47/47 [==============================] - 38s 803ms/step - loss: 0.0044 - lm_acc: 0.9999
#
# Epoch 00081: lm_acc did not improve from 0.99990
# Epoch 82/100
# 47/47 [==============================] - 38s 802ms/step - loss: 0.0042 - lm_acc: 0.9999
#
# Epoch 00082: lm_acc improved from 0.99990 to 0.99991, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 83/100
# 47/47 [==============================] - 38s 807ms/step - loss: 0.0041 - lm_acc: 0.9998
#
# Epoch 00083: lm_acc did not improve from 0.99991
# Epoch 84/100
# 47/47 [==============================] - 38s 808ms/step - loss: 0.0038 - lm_acc: 0.9999
#
# Epoch 00084: lm_acc improved from 0.99991 to 0.99995, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 85/100
# 47/47 [==============================] - 38s 806ms/step - loss: 0.0036 - lm_acc: 1.0000
#
# Epoch 00085: lm_acc improved from 0.99995 to 0.99995, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 86/100
# 47/47 [==============================] - 38s 807ms/step - loss: 0.0035 - lm_acc: 1.0000
#
# Epoch 00086: lm_acc improved from 0.99995 to 0.99996, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 87/100
# 47/47 [==============================] - 38s 808ms/step - loss: 0.0033 - lm_acc: 0.9999
#
# Epoch 00087: lm_acc did not improve from 0.99996
# Epoch 88/100
# 47/47 [==============================] - 38s 809ms/step - loss: 0.0032 - lm_acc: 1.0000
#
# Epoch 00088: lm_acc did not improve from 0.99996
# Epoch 89/100
# 47/47 [==============================] - 38s 802ms/step - loss: 0.0030 - lm_acc: 1.0000
#
# Epoch 00089: lm_acc improved from 0.99996 to 0.99996, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 90/100
# 47/47 [==============================] - 38s 811ms/step - loss: 0.0029 - lm_acc: 1.0000
#
# Epoch 00090: lm_acc did not improve from 0.99996
# Epoch 91/100
# 47/47 [==============================] - 38s 807ms/step - loss: 0.0028 - lm_acc: 1.0000
#
# Epoch 00091: lm_acc did not improve from 0.99996
# Epoch 92/100
# 47/47 [==============================] - 38s 809ms/step - loss: 0.0027 - lm_acc: 1.0000
#
# Epoch 00092: lm_acc improved from 0.99996 to 0.99997, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 93/100
# 47/47 [==============================] - 38s 808ms/step - loss: 0.0027 - lm_acc: 0.9999
#
# Epoch 00093: lm_acc did not improve from 0.99997
# Epoch 94/100
# 47/47 [==============================] - 38s 807ms/step - loss: 0.0025 - lm_acc: 1.0000
#
# Epoch 00094: lm_acc improved from 0.99997 to 0.99997, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 95/100
# 47/47 [==============================] - 38s 808ms/step - loss: 0.0024 - lm_acc: 1.0000
#
# Epoch 00095: lm_acc improved from 0.99997 to 0.99997, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 96/100
# 47/47 [==============================] - 38s 809ms/step - loss: 0.0023 - lm_acc: 1.0000
#
# Epoch 00096: lm_acc did not improve from 0.99997
# Epoch 97/100
# 47/47 [==============================] - 38s 808ms/step - loss: 0.0023 - lm_acc: 1.0000
#
# Epoch 00097: lm_acc improved from 0.99997 to 0.99999, saving model to /content/drive/MyDrive/data/data/songys/lstm_scale_dot.hdf5
# Epoch 98/100
# 47/47 [==============================] - 38s 807ms/step - loss: 0.0022 - lm_acc: 1.0000
#
# Epoch 00098: lm_acc did not improve from 0.99999
# Epoch 99/100
# 47/47 [==============================] - 38s 809ms/step - loss: 0.0022 - lm_acc: 1.0000
#
# Epoch 00099: lm_acc did not improve from 0.99999
# Epoch 100/100
# 47/47 [==============================] - 38s 808ms/step - loss: 0.0021 - lm_acc: 1.0000
#
# Epoch 00100: lm_acc did not improve from 0.99999

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['lm_acc'], 'g-', label='acc')
plt.xlabel('Epoch')
plt.legend()

plt.show()

# %% [markdown]
# ## Inference

# %%
# 모델 생성
model = build_model(len(vocab), d_model, n_enc_seq, n_dec_seq)
# train weight로 초기화
model.load_weights(os.path.join(songys_dir, 'lstm_scale_dot.hdf5'))
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 1, 32), dtype=tf.float32, name=None), name='tf.expand_dims_32/ExpandDims:0', description="created by layer 'tf.expand_dims_32'")

# %%
def do_chat(vocab, model, n_enc_seq, n_dec_seq, string):
    """
    seq2seq chat
    :param vocab: vocab
    :param model: model
    :param n_enc_seq: number of enc seqence
    :param n_dec_seq: number of dec seqence
    :param string: inpust string
    """
    # qeustion
    q = vocab.encode_as_pieces(string)
    q_id = [vocab.piece_to_id(p) for p in q][:n_enc_seq]
    q_id += [0] * (n_enc_seq - len(q_id))
    assert len(q_id) == n_enc_seq

    # answer
    a_id = [vocab.bos_id()]
    a_id += [0] * (n_dec_seq - len(a_id))
    assert len(a_id) == n_dec_seq

    # 처음부터 예측
    start_idx = 0

    for _ in range(start_idx, n_dec_seq - 1):
        outputs = model.predict((np.array([q_id]), np.array([a_id])))
        prob = outputs[0][start_idx]
        word_id = np.argmax(prob)
        if word_id == vocab.eos_id():
            break
        a_id[start_idx + 1] = int(word_id)
        start_idx += 1
    predict_id = a_id[1:start_idx + 1]
    predict_str = vocab.decode_ids(predict_id)
    return predict_str

# %%
while True:
    string = input('질문 > ')
    string = string.strip()
    if len(string) == 0:
        break
    predict_str = do_chat(vocab, model, n_enc_seq, n_dec_seq, string)
    print(f'답변 > {predict_str}')
# Out:
# 질문 > 안녕
# 답변 > 자식 시간만큼 같이 ⁇
# 질문 > 뭐라는 거니,,
# 답변 > 간단하고 둘 중.
# 질문 > 너는 누귄
# 답변 > 능력 능력만 능력만 같은 사람 맘 맘 맘 맘 맘 맘 맘 맘 맘 맘 맘 맘 맘고 맘합니다.
# 질문 > 잘 안되는구나..
# 답변 > 간단하고 있으면 있으면 아픈 게 있으면 아픈 게 예의 게 예의 게 예의 게 예의 예의 예의 예의 예의 예의 예의 예의 예의 예의 예
# 질문 >
